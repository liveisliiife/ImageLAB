# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")


raw_image = Image.open("image.jpg").convert('RGB')

"""
# conditional image captioning
text = "a photography of"
inputs = processor(raw_image, text, return_tensors="pt")

out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
"""


# unconditional image captioning
inputs = processor(raw_image, return_tensors="pt")

out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# arafed man making a clay pot on a wheel in a pottery shop

# %%
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# arafed man making a clay pot on a wheel in a pottery shop

# %%
raw_image2 = Image.open("image2.jpg").convert('RGB')

inputs2 = processor(raw_image2, return_tensors="pt")

out2 = model.generate(**inputs2)
print(processor.decode(out2[0], skip_special_tokens=True))
# Out:
# woman sitting in front of a fire with a pot on it

# %%
raw_image3 = Image.open("image3.jpg").convert('RGB')

inputs3 = processor(raw_image3, return_tensors="pt")

out3 = model.generate(**inputs3)
print(processor.decode(out3[0], skip_special_tokens=True))
# Out:
# there is a man riding a horse with a bow and arrow
