# %% [markdown]
# hazır stilleri kullanma

# %%
# 📦 Gerekli paketler
# !pip install torch torchvision pillow --quiet

# 📁 Repo ve modelleri al
# !git clone https://github.com/pytorch/examples.git
# %cd examples/fast_neural_style
# !python download_saved_models.py

# 📤 Görsel yükle
from google.colab import files
print("👉 Lütfen stil aktarımı yapılacak görseli yükle (örnek: ankara_gezi.jpg)")
uploaded = files.upload()

# 🖼️ Dosya adını al
import os
original_filename = list(uploaded.keys())[0]
basename, ext = os.path.splitext(original_filename)

# 🖼️ Görseli yükle ve yeniden boyutlandır
from PIL import Image

def load_and_resize(filename, size=512):
    img = Image.open(filename).convert('RGB')
    img = img.resize((size, size))
    resized_path = f"/content/examples/fast_neural_style/{filename}"
    img.save(resized_path)
    return resized_path

load_and_resize(original_filename)

# 🎨 Stil dosyaları
style_models = {
    "mosaic": "mosaic.pth",
    "candy": "candy.pth",
    "udnie": "udnie.pth",
    "rain_princess": "rain_princess.pth"
}

# 📁 Çıktıları saklamak için klasör oluştur
# !mkdir -p /content/stylized_outputs

# 🔁 Her stil için dönüşüm yap
for style_name, model_file in style_models.items():
    output_name = f"{basename}_{style_name}.jpg"
    output_path = f"/content/stylized_outputs/{output_name}"

    # !python neural_style/neural_style.py eval \
      --content-image "{original_filename}" \
      --output-image "{output_name}" \
      --model "saved_models/{model_file}"

    # Taşı ve yeniden adlandır
    # !mv "{output_name}" "/content/stylized_outputs/"

# 📦 Hepsini zip'le
# %cd /content/
# !zip -r stylized_images.zip stylized_outputs > /dev/null

# ✅ İndirilebilir hale getir
from google.colab import files
print("✅ Tüm stil dönüşümleri tamamlandı. Zip dosyası indirilebilir.")
files.download("stylized_images.zip")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.3 MB/s eta 0:00:00
# Cloning into 'examples'...
# remote: Enumerating objects: 4601, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (104/104), done.
# ...
